# %% [markdown]
# <a href="https://colab.research.google.com/github/ss86rg/DZ_9_icolab/blob/master/sem_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pit

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %% [markdown]
# 1. Изобразите отношение households к population с
# помощью точечного графика

# %%
sns.scatterplot(data=df, x='households',y='population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %% [markdown]
# 2. Визуализировать longitude по отношения к
# median_house_value, используя линейный график

# %%
sns.relplot(df, x='longitude', y='median_house_value', kind='line');

# %%
pit.figure(figsize=(16,10))
sns.lineplot(df, x='longitude', y='median_house_value');

# %%
sns.set(rc={'figure.figsize':(16,10)}) #  размер по умолчанию

# %% [markdown]
# 3. Представить гистограмму по housing_median_age

# %%
sns.histplot(df, x='housing_median_age', bins=30)# displot
pit.xticks(range(0,55,2))
pit.yticks(range(0,255,10));

# %% [markdown]
# 4. Изобразить гистограмму по median_house_value с
# оттенком housing_median_age

# %%
sns.histplot(df, x='median_house_value',hue='housing_median_age')
pit.xticks(range(0,550000,25000),rotation=45)
pit.yticks(range(0,26,1));

# %% [markdown]
# Задача №65. Решение в группах
# Написать EDA для датасета про пингвинов
# Необходимо:
# ● Использовать 2-3 точечных графика
# ● Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile
# ● Использовать PairGrid с типом графика на ваш выбор
# ● Изобразить Heatmap
# ● Использовать 2-3 гистограммы

# %%
penguins = sns.load_dataset("penguins")
penguins.head(20)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
# 16  Adelie  Torgersen            38.7           19.0              195.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# 3           NaN     NaN
# 4        3450.0  Female
# 5        3650.0    Male
# 6        3625.0  Female
# 7        4675.0    Male
# 8        3475.0     NaN
# 9        4250.0     NaN
# 10       3300.0     NaN
# 11       3700.0     NaN
# 12       3200.0  Female
# 13       3800.0    Male
# 14       4400.0    Male
# 15       3700.0  Female
# 16       3450.0  Female
# 17       4500.0    Male
# 18       3325.0  Female
# 19       4200.0    Male

# %%
sns.scatterplot(penguins, x='bill_length_mm',y='bill_depth_mm', hue='species', size='sex', style='island');

# %%
sns.scatterplot(penguins, x='flipper_length_mm',y='body_mass_g',hue='species', size='sex');

# %%
sns.scatterplot(penguins, x='bill_length_mm',y='body_mass_g', hue='species', size='sex');

# %% [markdown]
#  Использовать PairGrid с типом графика на ваш выбор

# %%
j = sns.PairGrid(penguins[['bill_depth_mm', 'bill_length_mm', 'body_mass_g', 'flipper_length_mm']])
j.map(sns.scatterplot);

# %%
corr_pg = penguins.corr()
corr_pg
# Out:
# <ipython-input-39-1b76ff1fa902>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_pg = penguins.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(corr_pg, annot=True, cmap='coolwarm', linewidths=1);

# %%
sns.histplot(penguins, x='bill_length_mm');

# %%
sns.histplot(penguins, x='body_mass_g');

# %%
sns.histplot(penguins, x='flipper_length_mm');

# %% [markdown]
# Создать новый столбец в таблице с
# пингвинами, который будет отвечать за
# показатель длины клюва пингвина.
# high - длинный(от 42)
# middle - средний(от 35 до 42)
# low - маленький(до 35)

# %%
penguins.loc[penguins['bill_length_mm'] >= 42, 'high_group'] = 'high'
penguins.loc[(penguins['bill_length_mm'] >= 35) & (penguins['bill_length_mm'] < 42), 'high_group'] = 'middle'
penguins.loc[penguins['bill_length_mm'] < 35, 'high_group'] = 'low'

# %%
penguins.sample(50)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 192  Chinstrap      Dream            49.0           19.5              210.0
# 146     Adelie      Dream            39.2           18.6              190.0
# 276     Gentoo     Biscoe            43.8           13.9              208.0
# 242     Gentoo     Biscoe            46.5           14.5              213.0
# 17      Adelie  Torgersen            42.5           20.7              197.0
# 158  Chinstrap      Dream            46.1           18.2              178.0
# 162  Chinstrap      Dream            46.6           17.8              193.0
# 68      Adelie  Torgersen            35.9           16.6              190.0
# 38      Adelie      Dream            37.6           19.3              181.0
# 112     Adelie     Biscoe            39.7           17.7              193.0
# 290     Gentoo     Biscoe            47.7           15.0              216.0
# 7       Adelie  Torgersen            39.2           19.6              195.0
# 120     Adelie  Torgersen            36.2           17.2              187.0
# 244     Gentoo     Biscoe            42.9           13.1              215.0
# 64      Adelie     Biscoe            36.4           17.1              184.0
# 24      Adelie     Biscoe            38.8           17.2              180.0
# 253     Gentoo     Biscoe            59.6           17.0              230.0
# 136     Adelie      Dream            35.6           17.5              191.0
# 197  Chinstrap      Dream            50.8           18.5              201.0
# 213  Chinstrap      Dream            46.8           16.5              189.0
# 265     Gentoo     Biscoe            43.6           13.9              217.0
# 175  Chinstrap      Dream            50.6           19.4              193.0
# 183  Chinstrap      Dream            54.2           20.8              201.0
# 108     Adelie     Biscoe            38.1           17.0              181.0
# 143     Adelie      Dream            40.7           17.0              190.0
# 293     Gentoo     Biscoe            46.5           14.8              217.0
# 145     Adelie      Dream            39.0           18.7              185.0
# 279     Gentoo     Biscoe            50.4           15.3              224.0
# 176  Chinstrap      Dream            46.7           17.9              195.0
# 321     Gentoo     Biscoe            55.9           17.0              228.0
# 248     Gentoo     Biscoe            48.2           14.3              210.0
# 121     Adelie  Torgersen            37.7           19.8              198.0
# 81      Adelie  Torgersen            42.9           17.6              196.0
# 11      Adelie  Torgersen            37.8           17.3              180.0
# 147     Adelie      Dream            36.6           18.4              184.0
# 307     Gentoo     Biscoe            51.3           14.2              218.0
# 238     Gentoo     Biscoe            46.2           14.5              209.0
# 233     Gentoo     Biscoe            48.4           14.6              213.0
# 19      Adelie  Torgersen            46.0           21.5              194.0
# 240     Gentoo     Biscoe            50.2           14.3              218.0
# 59      Adelie     Biscoe            37.6           19.1              194.0
# 343     Gentoo     Biscoe            49.9           16.1              213.0
# 250     Gentoo     Biscoe            47.3           15.3              222.0
# 247     Gentoo     Biscoe            47.8           15.0              215.0
# 15      Adelie  Torgersen            36.6           17.8              185.0
# 294     Gentoo     Biscoe            46.4           15.0              216.0
# 66      Adelie     Biscoe            35.5           16.2              195.0
# 181  Chinstrap      Dream            52.8           20.0              205.0
# 327     Gentoo     Biscoe            53.4           15.8              219.0
# 83      Adelie  Torgersen            35.1           19.4              193.0
#
#      body_mass_g     sex high_group
# 192       3950.0    Male       high
# 146       4250.0    Male     middle
# 276       4300.0  Female       high
# 242       4400.0  Female       high
# 17        4500.0    Male       high
# 158       3250.0  Female       high
# 162       3800.0  Female       high
# 68        3050.0  Female     middle
# 38        3300.0  Female     middle
# 112       3200.0  Female     middle
# 290       4750.0  Female       high
# 7         4675.0    Male     middle
# 120       3150.0  Female     middle
# 244       5000.0  Female       high
# 64        2850.0  Female     middle
# 24        3800.0    Male     middle
# 253       6050.0    Male       high
# 136       3175.0  Female     middle
# 197       4450.0    Male       high
# 213       3650.0  Female       high
# 265       4900.0  Female       high
# 175       3800.0    Male       high
# 183       4300.0    Male       high
# 108       3175.0  Female     middle
# 143       3725.0    Male     middle
# 293       5200.0  Female       high
# 145       3650.0    Male     middle
# 279       5550.0    Male       high
# 176       3300.0  Female       high
# 321       5600.0    Male       high
# 248       4600.0  Female       high
# 121       3500.0    Male     middle
# 81        4700.0    Male       high
# 11        3700.0     NaN     middle
# 147       3475.0  Female     middle
# 307       5300.0    Male       high
# 238       4800.0  Female       high
# 233       5850.0    Male       high
# 19        4200.0    Male       high
# 240       5700.0    Male       high
# 59        3750.0    Male     middle
# 343       5400.0    Male       high
# 250       5250.0    Male       high
# 247       5650.0    Male       high
# 15        3700.0  Female     middle
# 294       4700.0  Female       high
# 66        3350.0  Female     middle
# 181       4550.0    Male       high
# 327       5500.0    Male       high
# 83        4200.0    Male     middle

# %% [markdown]
# Изобразить гистограмму по flipper_length_mm
# с оттенком height_group. Сделать анализ

# %%
sns.histplot(penguins, x='flipper_length_mm', hue='high_group');
