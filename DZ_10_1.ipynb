# %% [markdown]
# <a href="https://colab.research.google.com/github/ss86rg/DZ_9_icolab/blob/master/DZ_10_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задача 44: В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?
#
# import random
# lst = ['robot'] * 10
# lst += ['human'] * 10
# random.shuffle(lst)
# data = pd.DataFrame({'whoAmI':lst})
# data.head()

# %%
import pandas as pd

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  robot
# 3  human
# 4  human

# %%
data
# Out:
#    whoAmI
# 0   human
# 1   human
# 2   robot
# 3   human
# 4   human
# 5   human
# 6   human
# 7   robot
# 8   robot
# 9   human
# 10  robot
# 11  robot
# 12  robot
# 13  human
# 14  human
# 15  human
# 16  robot
# 17  robot
# 18  robot
# 19  robot

# %%
data.loc[data['whoAmI'] != 'human', 'human'] = '1'

# %%
data.loc[data['whoAmI'] != 'human', 'human'] = '0'

# %%
data.drop(columns='whoAmI')
# Out:
#    human
# 0    NaN
# 1    NaN
# 2      1
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7      1
# 8      1
# 9    NaN
# 10     1
# 11     1
# 12     1
# 13   NaN
# 14   NaN
# 15   NaN
# 16     1
# 17     1
# 18     1
# 19     1

# %%
data
# Out:
#    whoAmI human
# 0   human   NaN
# 1   human   NaN
# 2   robot     1
# 3   human   NaN
# 4   human   NaN
# 5   human   NaN
# 6   human   NaN
# 7   robot     1
# 8   robot     1
# 9   human   NaN
# 10  robot     1
# 11  robot     1
# 12  robot     1
# 13  human   NaN
# 14  human   NaN
# 15  human   NaN
# 16  robot     1
# 17  robot     1
# 18  robot     1
# 19  robot     1
